# %%
# Conjunto de dados usado para analisar em escala global, o sexo, idade e nacionalidade que mais viajam usando viação aérea
# Base de dados usada no projeto extraída do portal: https://www.kaggle.com/datasets
# Link do dataset usado: https://www.kaggle.com/datasets/iamsouravbanerjee/airline-dataset

# %%
import pandas as pd
import numpy as np
data_frame = pd.read_csv('Airline Dataset.csv')

# %%
data_frame.head()
# Out:
#    Passenger ID First Name Last Name  Gender  Age Nationality  \
# 0         10856     Edithe    Leggis  Female   62       Japan
# 1         43872     Elwood      Catt    Male   62   Nicaragua
# 2         42633      Darby   Felgate    Male   67      Russia
# 3         78493   Dominica      Pyle  Female   71       China
# 4         82072        Bay   Pencost    Male   21       China
#
#                 Airport Name Airport Country Code   Country Name  \
# 0           Coldfoot Airport                   US  United States
# 1          Kugluktuk Airport                   CA         Canada
# 2     Grenoble-Isère Airport                   FR         France
# 3  Ottawa / Gatineau Airport                   CA         Canada
# 4            Gillespie Field                   US  United States
#
#   Airport Continent     Continents Departure Date Arrival Airport  \
# 0               NAM  North America      6/28/2022             CXF
# ...

# %%
data_frame.dtypes
# Out:
# Passenger ID             int64
# First Name              object
# Last Name               object
# Gender                  object
# Age                      int64
# Nationality             object
# Airport Name            object
# Airport Country Code    object
# Country Name            object
# Airport Continent       object
# Continents              object
# Departure Date          object
# Arrival Airport         object
# Pilot Name              object
# Flight Status           object
# dtype: object

# %%
data_frame.isna()
# Out:
#        Passenger ID  First Name  Last Name  Gender    Age  Nationality  \
# 0             False       False      False   False  False        False
# 1             False       False      False   False  False        False
# 2             False       False      False   False  False        False
# 3             False       False      False   False  False        False
# 4             False       False      False   False  False        False
# ...             ...         ...        ...     ...    ...          ...
# 98614         False       False      False   False  False        False
# 98615         False       False      False   False  False        False
# 98616         False       False      False   False  False        False
# 98617         False       False      False   False  False        False
# 98618         False       False      False   False  False        False
#
#        Airport Name  Airport Country Code  Country Name  Airport Continent  \
# ...

# %%
data_frame.notnull()
# Out:
#        Passenger ID  First Name  Last Name  Gender   Age  Nationality  \
# 0              True        True       True    True  True         True
# 1              True        True       True    True  True         True
# 2              True        True       True    True  True         True
# 3              True        True       True    True  True         True
# 4              True        True       True    True  True         True
# ...             ...         ...        ...     ...   ...          ...
# 98614          True        True       True    True  True         True
# 98615          True        True       True    True  True         True
# 98616          True        True       True    True  True         True
# 98617          True        True       True    True  True         True
# 98618          True        True       True    True  True         True
#
#        Airport Name  Airport Country Code  Country Name  Airport Continent  \
# ...

# %%
data_frame
# Out:
#        Passenger ID  First Name  Last Name  Gender  Age Nationality  \
# 0             10856      Edithe     Leggis  Female   62       Japan
# 1             43872      Elwood       Catt    Male   62   Nicaragua
# 2             42633       Darby    Felgate    Male   67      Russia
# 3             78493    Dominica       Pyle  Female   71       China
# 4             82072         Bay    Pencost    Male   21       China
# ...             ...         ...        ...     ...  ...         ...
# 98614         58454      Gareth    Mugford    Male   85       China
# 98615         22028       Kasey   Benedict  Female   19      Russia
# 98616         61732      Darrin     Lucken    Male   65   Indonesia
# 98617         19819       Gayle  Lievesley  Female   34       China
# 98618         14485  Wilhelmine     Touret  Female   10      Poland
#
#                       Airport Name Airport Country Code        Country Name  \
# ...

# %%
data_frame[['Gender','Age', 'Nationality']]
# Out:
#        Gender  Age Nationality
# 0      Female   62       Japan
# 1        Male   62   Nicaragua
# 2        Male   67      Russia
# 3      Female   71       China
# 4        Male   21       China
# ...       ...  ...         ...
# 98614    Male   85       China
# 98615  Female   19      Russia
# 98616    Male   65   Indonesia
# 98617  Female   34       China
# 98618  Female   10      Poland
#
# [98619 rows x 3 columns]

# %%
data_frame[[ 'Gender', 'Nationality']].describe()
# Out:
#        Gender Nationality
# count   98619       98619
# unique      2         240
# top      Male       China
# freq    49598       18317

# %%
data_frame[['Age', 'Gender']].describe()
# Out:
#                 Age
# count  98619.000000
# mean      45.504021
# std       25.929849
# min        1.000000
# 25%       23.000000
# 50%       46.000000
# 75%       68.000000
# max       90.000000

# %%
df2 = data_frame.query('Age > 40 ')
display(df2)
# Out:
#        Passenger ID First Name  Last Name  Gender  Age Nationality  \
# 0             10856     Edithe     Leggis  Female   62       Japan
# 1             43872     Elwood       Catt    Male   62   Nicaragua
# 2             42633      Darby    Felgate    Male   67      Russia
# 3             78493   Dominica       Pyle  Female   71       China
# 5             39630       Lora    Durbann  Female   55      Brazil
# ...             ...        ...        ...     ...  ...         ...
# 98611         37761     Hadria     Vacher  Female   41      Canada
# 98612         26208        Ody    Tineman    Male   82   Indonesia
# 98613         95651     Oneida  Ossipenko  Female   47      Serbia
# 98614         58454     Gareth    Mugford    Male   85       China
# 98616         61732     Darrin     Lucken    Male   65   Indonesia
#
#                             Airport Name Airport Country Code   Country Name  \
# 0                       Coldfoot Airport                   US  United States
# ...

# %%
df2.Age.describe()
# Out:
# count    54917.000000
# mean        65.404356
# std         14.431742
# min         41.000000
# 25%         53.000000
# 50%         65.000000
# 75%         78.000000
# max         90.000000
# Name: Age, dtype: float64

# %%
df2[['Gender', 'Age', 'Nationality']].groupby(['Gender', 'Nationality']).mean()
# Out:
#                                 Age
# Gender Nationality
# Female Afghanistan        64.171429
#        Aland Islands      68.714286
#        Albania            65.592920
#        Algeria            51.500000
#        American Samoa     68.222222
# ...                             ...
# Male   Wallis and Futuna  76.000000
#        Western Sahara     62.000000
#        Yemen              66.870000
#        Zambia             68.875000
#        Zimbabwe           67.121212
#
# [457 rows x 1 columns]
